# %% [markdown]
# # Preprocessing

# %%
import os
import sys
import cv2
from pathlib import Path
import re
#import shutil
#import random
#from shutil import copyfile
import numpy as np

import matplotlib.pyplot as plt

# sklearn tools
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report


# tf tools
from tensorflow.keras.datasets import cifar10 #Our data
from tensorflow.keras.models import Sequential #Our Model
from tensorflow.keras.layers import (Conv2D, #Our layers
                                     MaxPooling2D, 
                                     Activation, 
                                     Flatten, 
                                     Dense)
from tensorflow.keras.utils import plot_model #Plotting 
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K

# %% [markdown]
# ## FInd and create labels

# %%
#Path to training folder with painters
training_dir = os.path.join("..", "data", "small_training")
#Names as a string
label_names = []
#Training labels
trainY = []
#Counter variable
i = 0
#For each folder in the training data
for folder in Path(training_dir).glob("*"):
    #Find painters name
    painter = re.findall(r"(?!.*/).+", str(folder))
    #Append the painters names to the list "label_names"
    label_names.append(painter[0])
    #For each image in the folder
    for img in folder.glob("*"):
        #append the folder index (e.g. the label)
        trainY.append(i)
    #Increase counter by 1    
    i +=1

# %%
#Path to test folder with painters
test_dir = os.path.join("..", "data", "small_validation")  
#Test labels
testY = []  
#Counter
i = 0
#For each folder in the test data
for folder in Path(test_dir).glob("*"):
    #For each image in the folder
    for img in folder.glob("*"):
        #Aooend the folder index (e.g. the label)
        testY.append(i)
    #Increase by 1
    i +=1

# %%
#Binariser
lb = LabelBinarizer()
#Transform labels 0-9 into binary labels
trainY = lb.fit_transform(trainY)
testY = lb.fit_transform(testY)

# %% [markdown]
# ## Resize images

# %%
#Function for resizing images and converting it to value between zero and 1
def resize_imgs(folder_path, dimensions):
    #List of image sizes
    images = []
    #Folder  each folder in training data
    for folder in Path(folder_path).glob("*"):
        # For each file in the folder
        for image in Path(folder).glob("*"):
            #read image
            image = cv2.imread(str(image))
            #resize image
            image = cv2.resize(image, dimensions, interpolation = cv2.INTER_AREA)
            #append image to array and convert it to a value between 0 and 1
            images.append(image.astype("float")/255.)
    return images

# %%
# Rezise training data
# The path were the training images are located
filepath_training = os.path.join("..", "data", "small_training")
# Create training data
trainX = resize_imgs(filepath_training, (120, 120))

# Resize validation data
# The path were the test images are located
filepath_validation = os.path.join("..", "data", "small_validation")
#Create test data
testX =resize_imgs(filepath_validation, (120,120))

# %%
#Convert data to numpy arrays
testX = np.array(testX)
trainX = np.array(trainX)

# %% [markdown]
# ## Modelling

# %%
def plot_history(H, epochs):
    # visualize performance
    plt.style.use("fivethirtyeight")
    fig = plt.figure()
    plt.plot(np.arange(0, epochs), H.history["loss"], label="train_loss")
    plt.plot(np.arange(0, epochs), H.history["val_loss"], label="val_loss")
    plt.plot(np.arange(0, epochs), H.history["accuracy"], label="train_acc")
    plt.plot(np.arange(0, epochs), H.history["val_accuracy"], label="val_acc")
    plt.title("Training Loss and Accuracy")
    plt.xlabel("Epoch #")
    plt.ylabel("Loss/Accuracy")
    plt.legend()
    plt.tight_layout()
    plt.show()
    fig.savefig("../output/performance.png")

# %%
# define model
model = Sequential()

# first set of CONV => RELU => POOL

#Conv
model.add(Conv2D(32, (3, 3), 
                 padding="same", 
                 input_shape= (120, 120, 3)))
#Relu
model.add(Activation("relu"))
#Pool
model.add(MaxPooling2D(pool_size=(2, 2), 
                       strides=(2, 2)))

# second set of CONV => RELU => POOL
#Conv
model.add(Conv2D(50, (5, 5), 
                 padding="same"))
#Relu
model.add(Activation("relu"))
#Pool
model.add(MaxPooling2D(pool_size=(2, 2), 
                       strides=(2, 2)))

# FC => RELU
#flatten
model.add(Flatten())
#Add layer
model.add(Dense(500))
#Relu
model.add(Activation("relu"))

# softmax classifier
#layer
model.add(Dense(10))
#Activation
model.add(Activation("softmax"))

# %%
#Our optimizer with the stochastic descent (our learning rate is here 0.1 it can be between 0.001 and 0.01)
opt = SGD(lr=0.01)
model.compile(loss="categorical_crossentropy",
              optimizer=opt,
              metrics=["accuracy"])

# %%
#Create a summary of the model
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 319, 422, 32)      896
# _________________________________________________________________
# activation_8 (Activation)    (None, 319, 422, 32)      0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 159, 211, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 159, 211, 50)      40050
# _________________________________________________________________
# activation_9 (Activation)    (None, 159, 211, 50)      0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 79, 105, 50)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 414750)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               207375500
# _________________________________________________________________
# activation_10 (Activation)   (None, 500)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5010
# _________________________________________________________________
# activation_11 (Activation)   (None, 10)                0
# =================================================================
# Total params: 207,421,456
# Trainable params: 207,421,456
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file = "../output/model_architecture.png", show_shapes=True, show_layer_names=True)

# %%
# train model
H = model.fit(trainX, trainY, 
              validation_data=(testX, testY), 
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 13/13 [==============================] - 31s 2s/step - loss: 2.7662 - accuracy: 0.0802 - val_loss: 2.2833 - val_accuracy: 0.1900
# Epoch 2/20
# 13/13 [==============================] - 30s 2s/step - loss: 2.2685 - accuracy: 0.2241 - val_loss: 2.2415 - val_accuracy: 0.1600
# Epoch 3/20
# 13/13 [==============================] - 30s 2s/step - loss: 2.2070 - accuracy: 0.1869 - val_loss: 2.2131 - val_accuracy: 0.1900
# Epoch 4/20
# 13/13 [==============================] - 30s 2s/step - loss: 2.1682 - accuracy: 0.2300 - val_loss: 2.3109 - val_accuracy: 0.1100
# Epoch 5/20
# 13/13 [==============================] - 31s 2s/step - loss: 2.1492 - accuracy: 0.2709 - val_loss: 2.2638 - val_accuracy: 0.1500
# Epoch 6/20
# 13/13 [==============================] - 30s 2s/step - loss: 2.0984 - accuracy: 0.2595 - val_loss: 2.3129 - val_accuracy: 0.1400
# Epoch 7/20
# 13/13 [==============================] - 30s 2s/step - loss: 2.0068 - accuracy: 0.2514 - val_loss: 2.3425 - val_accuracy: 0.1400
# Epoch 8/20
# 13/13 [==============================] - 30s 2s/step - loss: 1.9756 - accuracy: 0.3100 - val_loss: 2.1173 - val_accuracy: 0.2200
# Epoch 9/20
# 13/13 [==============================] - 31s 2s/step - loss: 1.8245 - accuracy: 0.4354 - val_loss: 2.2479 - val_accuracy: 0.2000
# Epoch 10/20
# 13/13 [==============================] - 31s 2s/step - loss: 1.8948 - accuracy: 0.3747 - val_loss: 2.3486 - val_accuracy: 0.1900
# Epoch 11/20
# 13/13 [==============================] - 30s 2s/step - loss: 1.7692 - accuracy: 0.4020 - val_loss: 2.2574 - val_accuracy: 0.1600
# Epoch 12/20
# 13/13 [==============================] - 31s 2s/step - loss: 1.5863 - accuracy: 0.4788 - val_loss: 2.4909 - val_accuracy: 0.1200
# Epoch 13/20
# 13/13 [==============================] - 31s 2s/step - loss: 1.5177 - accuracy: 0.5646 - val_loss: 2.3220 - val_accuracy: 0.2200
# Epoch 14/20
# 13/13 [==============================] - 32s 2s/step - loss: 1.4822 - accuracy: 0.5129 - val_loss: 2.4953 - val_accuracy: 0.1300
# Epoch 15/20
# 13/13 [==============================] - 31s 2s/step - loss: 1.7226 - accuracy: 0.4821 - val_loss: 2.8132 - val_accuracy: 0.1400
# Epoch 16/20
# 13/13 [==============================] - 30s 2s/step - loss: 1.1344 - accuracy: 0.6090 - val_loss: 3.0686 - val_accuracy: 0.1800
# Epoch 17/20
# 13/13 [==============================] - 30s 2s/step - loss: 1.1164 - accuracy: 0.7009 - val_loss: 2.6253 - val_accuracy: 0.2100
# Epoch 18/20
# 13/13 [==============================] - 30s 2s/step - loss: 0.7413 - accuracy: 0.8262 - val_loss: 2.6675 - val_accuracy: 0.1900
# Epoch 19/20
# 13/13 [==============================] - 30s 2s/step - loss: 0.8303 - accuracy: 0.7802 - val_loss: 2.7500 - val_accuracy: 0.1600
# Epoch 20/20
# 13/13 [==============================] - 31s 2s/step - loss: 0.6272 - accuracy: 0.8596 - val_loss: 2.8557 - val_accuracy: 0.2000

# %%
#Plot performance pr. epoch
plot_history(H,20)

# %%
#Print classification report
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
#               precision    recall  f1-score   support
#
#       Renoir       0.33      0.10      0.15        10
#      Matisse       0.40      0.20      0.27        10
#     Pissarro       1.00      0.10      0.18        10
#       Hassam       0.08      0.10      0.09        10
#      VanGogh       0.17      0.60      0.27        10
#      Sargent       0.43      0.30      0.35        10
#        Degas       0.00      0.00      0.00        10
#        Monet       0.17      0.20      0.18        10
#      Gauguin       0.20      0.40      0.27        10
#      Cezanne       0.00      0.00      0.00        10
#
#     accuracy                           0.20       100
#    macro avg       0.28      0.20      0.18       100
# weighted avg       0.28      0.20      0.18       100
# /home/cds-au590388/cds-visual/cv101/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/cds-au590388/cds-visual/cv101/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/cds-au590388/cds-visual/cv101/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
